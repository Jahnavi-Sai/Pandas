# %% [markdown]
# # ``GDP analysis using pandas + matplotlib + seaborn``
#
# ![ChatGPT Image May 17, 2025, 12_51_55 PM.jpg](attachment:d36a335d-ee9e-486b-854c-6acdf32fffb3.jpg)

# %% [markdown]
# # pandas (Python Data Analysis Library)
#
# pandas is a powerful open-source library used for data manipulation and analysis. It provides data structures and functions to efficiently work with structured data.
#
# ``Typical GDP Use Cases in pandas:``
#
# 1. Loading GDP data from CSV, Excel, JSON formats.
#
# 2. Filtering GDP data by country, year, or region.
#
# 3. Performing grouping and aggregation, e.g., mean GDP per continent.
#
# 4. Calculating growth rates using .pct_change().
#
# 5. Pivoting and reshaping for comparative analysis.
#
# ``Purpose:``
# Manipulate, clean, and analyze tabular data.

# %% [markdown]
# # matplotlib (Visualization Library)
#
# matplotlib is the foundation plotting library in Python used to generate static, animated, and interactive plots.
#
# ``Why Use matplotlib for GDP Analysis?``
#
# 1. Create detailed, publication-quality line plots for GDP over time.
#
# 2. Customize axis labels, titles, ticks, legends, gridlines, etc.
#
# 3. Save visualizations as images or PDFs for reports.
#
# ``Purpose:``
# Create basic plots like line graphs, bar charts, and scatter plots.

# %% [markdown]
# # seaborn (Statistical Data Visualization)
#
# seaborn is a high-level visualization library built on top of matplotlib. It simplifies the creation of aesthetically pleasing and informative statistical graphics.
#
# ``Why Use seaborn for GDP Analysis?``
#
# 1. Automatically integrates with pandas DataFrames.
#
# 2. Built-in support for color themes and aggregation.
#
# 3. Easier syntax for creating heatmaps, violin plots, regression plots, etc.
#
# 4. Best for comparative and trend analysis.
#
# ``Purpose:``
# Enhance visualizations with clean aesthetics and statistical insights.

# %% [markdown]
# # About GDP data- we used dataframe of gdp

# %% [markdown]
# | Term          | Definition                                                                                                                                                                                  |
# | ------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Dataset**   | A **collection of data**, often stored in files like CSV, Excel, JSON, SQL, etc. It represents information but isn't bound to a specific programming tool or format.
# |**DemographicData.csv**| → **Dataset**| |
# | **DataFrame** | A **specific data structure** provided by the `pandas` library in Python. It is used to **load, store, and manipulate datasets in memory** in a structured tabular form (rows and columns)
# |**stats** |→ **DataFrame holding that dataset inside Python**|
#  |

# %% [markdown]
# # What is GDP?
# GDP (Gross Domestic Product) is the total monetary value of all final goods and services produced within a country's borders in a specific time period (usually a year or a quarter).
#
# It is one of the most important indicators used to measure the economic performance of a country.

# %% [markdown]
# GDP ``=``total income a country earns from everything it produces and sells in a year — including goods (like cars, food, electronics) and services (like banking, education, tourism).
#
# ``Why is GDP Important?``

# %% [markdown]
# | Purpose                      | Explanation                                                                 |
# | ---------------------------- | --------------------------------------------------------------------------- |
# | Measures Economic Health  | A rising GDP means economic growth; a falling GDP may signal a recession.   |
# | Compares Living Standards | Higher GDP per capita usually means a higher standard of living.            |
# | Global Comparison         | Used to compare economies across countries (e.g., India vs. USA vs. China). |
# | Policy Making             | Helps governments make decisions on interest rates, taxes, and spending.    |

# %% [markdown]
# ``The dataset contains the following labels (column names):``
#
# | **Label**       | **Description**                                         |
# | --------------- | ------------------------------------------------------- |
# | `CountryName`   | Name of the country                                     |
# | `CountryCode`   | ISO code for the country                                |
# | `BirthRate`     | Birth rate per 1,000 people                             |
# | `InternetUsers` | Percentage of internet users in the population          |
# | `IncomeGroup`   | Economic classification (e.g., Low income, High income) |

# %% [markdown]
# Pandas is a very good package for dataframes and it is also perfect for daatset.

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91630\Desktop\FULL STACK DATASCIENCE AND GENAI\ClASSR00M\3. FEB ClASSR00M\13th FEB- gdp analysis project\13th\DataFrame_ Pandas\data.csv")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(df) # no of rows
# Out:
# 195

# %%
df.shape # the dimension like rows,columns= height,width
# Out:
# (195, 5)

# %%
df.columns # display all columns in the dataframe
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info() # gives complete information about dataframe like shape,datatypes,type,memory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
len(df.columns) # the no count of colunms i.e length
# Out:
# 5

# %%
df.head() # it displays top 5 rows of the dataframe defaulty
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()  # it displays bottom 5 rows of the dataframe defaulty
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.head(6) # we can give arugments as per the requirements
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
df.tail(6) # we can give arugments as per the requirements
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 189             Samoa         WSM     26.172           15.3
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %% [markdown]
# # slicing

# %%
df[ : :-1] # completely reversing of the dataframe
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[4:9] # from 4th row to 8th row
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
# 8             Australia         AUS     13.200           83.0
#
#            IncomeGroup
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income

# %%
df[3:] # from 3rd row to till last
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
df[ :8] # from starting row 0 to 7th row
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
df[0:100:10] # from 0th row to 100 row with step count of 10
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244      78.900000          High income
# 10  Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20     Belarus         BLR     12.500      54.170000  Upper middle income
# 30      Canada         CAN     10.900      85.800000          High income
# 40  Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50     Ecuador         ECU     21.070      40.353684  Upper middle income
# 60       Gabon         GAB     30.555       9.200000  Upper middle income
# 70   Greenland         GRL     14.500      65.800000          High income
# 80       India         IND     20.291      15.100000  Lower middle income
# 90  Kazakhstan         KAZ     22.730      54.000000  Upper middle income

# %% [markdown]
# # Descriptive statistics for the numerical columns in a DataFrame.
#
# | **Statistic**  | **Description**                                                       |
# | -------------- | --------------------------------------------------------------------- |
# | `count`        | Number of non-null (non-missing) entries                              |
# | `mean`         | Arithmetic mean (average) of the values                               |
# | `std`          | Standard deviation, measuring how spread out the values are           |
# | `min`          | Minimum value in the column                                           |
# | `25%` (Q1)     | 25th percentile (first quartile) – 25% of values are below this point |
# | `50%` (median) | 50th percentile (second quartile or median) – middle value            |
# | `75%` (Q3)     | 75th percentile (third quartile) – 75% of values are below this point |
# | `max`          | Maximum value in the column                                           |

# %%
df.describe() # describe means descrptive statistics
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.describe().transpose() # convert rows to columns or columns to rows
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
# if we want to change column name we will use list operator 
df.columns=['Name','Code','bR','Netusers','IGroup']

# %%
df.columns
# Out:
# Index(['Name', 'Code', 'bR', 'Netusers', 'IGroup'], dtype='object')

# %%
df.head()
# Out:
#                    Name Code      bR  Netusers               IGroup
# 0                 Aruba  ABW  10.244      78.9          High income
# 1           Afghanistan  AFG  35.253       5.9           Low income
# 2                Angola  AGO  45.985      19.1  Upper middle income
# 3               Albania  ALB  12.877      57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044      88.0          High income

# %%
# as same we can change the column names to normal by using list operator
df.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# if we want to print 2 or 3 columns we use this statement
df[['CountryName','CountryCode']] # we displayed only 2 columns
# Out:
#               CountryName CountryCode
# 0                   Aruba         ABW
# 1             Afghanistan         AFG
# 2                  Angola         AGO
# 3                 Albania         ALB
# 4    United Arab Emirates         ARE
# ..                    ...         ...
# 190           Yemen, Rep.         YEM
# 191          South Africa         ZAF
# 192      Congo, Dem. Rep.         COD
# 193                Zambia         ZMB
# 194              Zimbabwe         ZWE
#
# [195 rows x 2 columns]

# %%
df.isnull() # it checks the dataframe compeletely wheather it contains null value or not if null value is their 
# we print True or else False
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum() # it displays the column names with sum count it it has null the no will display
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df_categorical=df[['CountryName','CountryCode','IncomeGroup']]

# %%
df_categorical # we displayed only categorical values
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_categorical.describe() # because it is catergorical data only count,unique,top freq are calculated
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df_categorical.head().transpose() # we transposes the categorical value values of top 5
# Out:
#                        0            1                    2  \
# CountryName        Aruba  Afghanistan               Angola
# CountryCode          ABW          AFG                  AGO
# IncomeGroup  High income   Low income  Upper middle income
#
#                                3                     4
# CountryName              Albania  United Arab Emirates
# CountryCode                  ALB                   ARE
# IncomeGroup  Upper middle income           High income

# %%
df_numerical=df[['BirthRate','InternetUsers']]
df_numerical # we displayed only numerical data
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df_numerical.describe() # numerical data can calculate min,max,count,50% ...etc
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_numerical.head().transpose() # we transpose the numerical data values of top 5
# Out:
#                     0       1       2       3       4
# BirthRate      10.244  35.253  45.985  12.877  11.044
# InternetUsers  78.900   5.900  19.100  57.200  88.000

# %% [markdown]
# slicing in dataframe

# %%
df[['CountryName','CountryCode','IncomeGroup']][3:6]
# Out:
#             CountryName CountryCode          IncomeGroup
# 3               Albania         ALB  Upper middle income
# 4  United Arab Emirates         ARE          High income
# 5             Argentina         ARG          High income

# %%
df[3:6][['CountryName','CountryCode','IncomeGroup']]
# Out:
#             CountryName CountryCode          IncomeGroup
# 3               Albania         ALB  Upper middle income
# 4  United Arab Emirates         ARE          High income
# 5             Argentina         ARG          High income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# If we want to multipy two columns and add the the existing dataframe we use this command

# %%
df['BR*IU']=df.BirthRate * df.InternetUsers # we added a new column called calc to the dataframe
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup     BR*IU
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
len(df.columns)
# Out:
# 6

# %%
df.info() # we got the extra column details like  non-null,dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
#  5   BR*IU          195 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 9.3+ KB

# %%
df=df.drop('BR*IU',axis=1) # we deleted the BR*IU axis=1 means 1 is column 0 is row it is column nmae so we gave 1 in axis

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# here we are giving the statement like we need internetusers which are greater than 4

# %%
df.InternetUsers<4 # command we given but we got boolean values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter=df.InternetUsers<4
Filter                    # by assigning the varaiable also we got the boolean values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[Filter] # inserting the filter in the df we got the records greater than 50-- internetusers
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 117                   Myanmar         MMR     18.119            1.6
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# 156                   Somalia         SOM     43.891            1.5
# ...

# %% [markdown]
# here we are giving the statement like we need BirthRate which are greater than 50

# %%
df.BirthRate>45 # command we given but we got boolean values
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
Filter1=df.BirthRate>45
Filter1                   # by assigning the varaiable also we got the boolean values
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
df[Filter1] # inserting the filter in the df we got the records
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 2        Angola         AGO     45.985           19.1  Upper middle income
# 127       Niger         NER     49.661            1.7           Low income
# 167        Chad         TCD     45.745            2.3           Low income

# %%
df[Filter & Filter1] # we got the records birthrate is lessthan 45 and internet users are greater than 4 is 2 rows
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 127       Niger         NER     49.661            1.7  Low income
# 167        Chad         TCD     45.745            2.3  Low income

# %%
df[df.IncomeGroup=='High income'] # wer want how many high income in income group we use this command
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
df.IncomeGroup.unique() # we got how many labels in the incomegrop it dispalys
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df.IncomeGroup.nunique() # we got the label count in incomegroup
# Out:
# 4

# %% [markdown]
# # Mathplotlib
# matplotlib is the foundation plotting library in Python used to generate static, animated, and interactive plots.

# %% [markdown]
# # Seaborn - Used for the statistical  visualization i.e advance plot

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline    # we changed the size of the graph to 5 height,5 width
plt.rcParams['figure.figsize']=4,3
# Out:
# UsageError: unrecognized arguments: # we changed the size of the graph to 5 height,5 width

# %%
import warnings # for the os error update we ignore warnings
warnings.filterwarnings('ignore')

# %%
df["InternetUsers"] # it gives the internetusers records

# %% [markdown]
# # The distplot
#
# A distplot (short for distribution plot) is used to visualize the distribution of a continuous (numeric) variable.
#
# It shows how values in the data are distributed, often highlighting patterns like normal distribution, skewness, or multimodal behavior.
#
# the distplot is a combination of histogram with a line (density plot ) on it. we used the one univariaent analysis
#
# ``A typical dist plot may include:``
#
# Histogram – a bar plot showing how frequently values appear in intervals (bins).
#
# KDE (Kernel Density Estimate) – a smooth curve that estimates the probability density function of the variable.

# %%
vis1=sns.distplot(df["InternetUsers"])

# %%
vis2=sns.distplot(df["InternetUsers"],bins=10) # 10 bins=10 total histogram

# %% [markdown]
# # displot
# s a high-level Seaborn function for plotting distributions of a continuous numeric variable.
#
# ``It is used to visualize how values are spread across an interval, typically by combining:``
#
# 1. Histograms
#
# 2. KDE plots (optional)
#
# 3. Faceted plots (when using multiple categories)

# %%
vis3=sns.displot(df["InternetUsers"])

# %%
df[['InternetUsers','BirthRate']]

# %% [markdown]
# # The box plot:
#
# A box plot is a standardized way of displaying the distribution of a numerical variable based on five summary statistics:
#
# --Minimum (excluding outliers)
#
# --1st Quartile (Q1) – 25th percentile
#
# --Median (Q2) – 50th percentile
#
# --3rd Quartile (Q3) – 75th percentile
#
# --Maximum (excluding outliers)
#
# --t also highlights outliers and skewness.
#
# ``Purpose of Box Plot:``
#
# 1.To understand data spread and symmetry
#
# 2.To compare distributions across groups
#
# 3.To identify outliers
#
# 4.To analyze central tendency and variability
#
#
#
#
# ![bp.png](attachment:cddb4832-3f10-4a41-ae6e-27b9036d658c.png)

# %%
vis4=sns.boxplot(data=df,x='IncomeGroup',y='BirthRate')

# %% [markdown]
# # The LM Plot
#
# An lmplot in Seaborn is a scatter plot with a linear regression line (fit line) and confidence interval.
# It shows the relationship between two continuous variables, with optional categorical separation (like income group, gender, etc)
#
# ``Use Cases:``
#
# Visualize linear trends between variables (e.g., GDP vs Population)
#
# Detect correlation strength and direction
#
# Show groupwise regression using the hue argument
#
# Great for exploratory data analysis (EDA)

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate')

# %% [markdown]
# if we use fit reg =True then it gives regression line False then it delete regression line

# %%
vis6=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True)

# %%
vis7=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False)

# %%
vis6=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True, hue='IncomeGroup') 
# hue- Color-code the data points and regression lines by each category
# if we want to understand the graph divide into 4 parts

# %% [markdown]
# ``In this we learned about:``
#
# 1. importing data into python
#
# 2. Dataframe via pandas
#
# 3. exploring dataset
#
# 4. subsetting dataframes
#
# 5. basic operations with dataframe
#
# 6. filtering dataframes
#
# 7. Seaborn introduction
